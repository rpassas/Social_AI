# %%
import matplotlib.pyplot as plt
import sys
import numpy as np
sys.path.append('../')
from sandbox.world import World

# %% [markdown]
# ### One agent has static predictions

# %%
world = World(state_size=50, time =500, agent=["base", "base"], seed=7, pred_a= [0,1], prediction=["sigmoid", "sigmoid"], behavior=["sigmoid", "sigmoid"], attention=["static", "static"])

world.create_agents()
world.run()
agents = world.get_agents()
error = world.get_avg_abs_error()
preds = world.get_pred()
priors = world.get_behav_priors()
costs = world.get_costs()
predictability = world.get_predictability()
tru_dif = world.get_tru_dif()

#world.print_results()
time = [t for t in range(len(costs[0]))]

# %%
plt.figure(facecolor='white') 
plt.plot(time, error[0], 'g', label=agents[0])
plt.plot(time, error[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.xlabel("time")
plt.ylabel("error")
plt.title("Reality")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, costs[0], 'g', label=agents[0])
plt.plot(time, costs[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Costs")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, predictability[0], 'g', label=agents[0])
plt.plot(time, predictability[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Predictability")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, tru_dif[0], 'g', label=agents[0])
plt.plot(time, tru_dif[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("True Difference between Priors & Predictions")
plt.show()

# %% [markdown]
# ### Both Agents update predictions

# %%
world = World(state_size =4, time =100, agent=["base", "base"], pred_a= [0.2,0.2], behav_a= [0,0], prediction=["sigmoid", "sigmoid"], behavior=["sigmoid", "sigmoid"], attention=["static", "static"])

world.create_agents()
world.run()
agents = world.get_agents()
error = world.get_avg_abs_error()
preds = world.get_pred()
priors = world.get_behav_priors()
costs = world.get_costs()
predictability = world.get_predictability()
tru_dif = world.get_tru_dif()

#world.print_results()
time = [t for t in range(len(costs[0]))]

# %%
plt.figure(facecolor='white') 
plt.plot(time, priors[0], 'g', label=agents[0])
plt.plot(time, priors[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Priors")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, error[0], 'g', label=agents[0])
plt.plot(time, error[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Error")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, costs[0], 'g', label=agents[0])
plt.plot(time, costs[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Costs")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, predictability[0], 'g', label=agents[0])
plt.plot(time, predictability[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Predictability")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, tru_dif[0], 'g', label=agents[0])
plt.plot(time, tru_dif[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("True Difference between Priors & Predictions")
plt.show()

# %% [markdown]
# ### One agent also updates its behavior model, but not its prediction

# %%
world = World(state_size =50, time =500, agent=["base", "base"], seed=7, pred_a= [.1,0], behav_a= [0,.1], prediction=["sigmoid", "sigmoid"], behavior=["sigmoid", "sigmoid"], attention=["static", "static"])

world.create_agents()
world.run()
agents = world.get_agents()
error = world.get_avg_abs_error()
preds = world.get_pred()
priors = world.get_behav_priors()
costs = world.get_costs()
predictability = world.get_predictability()
tru_dif = world.get_tru_dif()

#world.print_results()
time = [t for t in range(len(costs[0]))]

# %%
plt.figure(facecolor='white') 
plt.plot(time, error[0], 'g', label=agents[0])
plt.plot(time, error[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Error")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, costs[0], 'g', label=agents[0])
plt.plot(time, costs[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Costs")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, predictability[0], 'g', label=agents[0])
plt.plot(time, predictability[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Predictability")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, tru_dif[0], 'g', label=agents[0])
plt.plot(time, tru_dif[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("True Difference between Priors & Predictions")
plt.show()

# %% [markdown]
# ### Let's change the adjustment rate

# %%
world = World(state_size =50, time =500, agent=["base", "base"], seed=12, pred_a= [1,0], behav_a= [0,1], prediction=["sigmoid", "sigmoid"], behavior=["sigmoid", "sigmoid"], attention=["static", "static"])

world.create_agents()
world.run()
agents = world.get_agents()
error = world.get_avg_abs_error()
preds = world.get_pred()
priors = world.get_behav_priors()
costs = world.get_costs()
predictability = world.get_predictability()
tru_dif = world.get_tru_dif()

#world.print_results()
time = [t for t in range(len(costs[0]))]

# %%
plt.figure(facecolor='white') 
plt.plot(time, error[0], 'g', label=agents[0])
plt.plot(time, error[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Error")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, costs[0], 'g', label=agents[0])
plt.plot(time, costs[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Costs")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, predictability[0], 'g', label=agents[0])
plt.plot(time, predictability[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("Predictability")
plt.show()

# %%
plt.figure(facecolor='white') 
plt.plot(time, tru_dif[0], 'g', label=agents[0])
plt.plot(time, tru_dif[1], 'r', label=agents[1])
plt.ylim([0, 1])
plt.legend()
plt.title("True Difference between Priors & Predictions")
plt.show()

# %%
y = np.random.uniform(0.4,0.9,200)
noise = np.random.uniform(0.8,1,100)
noisee = np.random.uniform(0.3,1, 200)
noise = np.append(noisee, noise)
yy = np.linspace(0.7,0.3,300)
yy = yy*noise
y = np.append(y,yy)
z = np.random.uniform(0.4,0.8,200)
zz = np.linspace(0.8,0.1,300)
zz = zz*noise
z = np.append(z,zz)

plt.figure(facecolor='white') 
plt.plot(time, y, 'g', label="prediction alpha: 0")
plt.plot(time, z, 'r', label="prediction alpha: 1")
plt.ylim([0, 1])
plt.legend()
plt.xlabel("time")
plt.ylabel("error")
plt.title("What we hope we'd see (not reality)")
plt.show()
